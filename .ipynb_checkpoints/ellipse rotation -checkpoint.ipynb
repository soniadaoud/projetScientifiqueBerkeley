# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Ellipse

delta = 45.0  # degrees
angles = np.arange(0, 360 + delta, delta)
ells = [Ellipse ( (0, 0), 4, 3, a ) for a in angles   ]
ells1 = [Ellipse ( (2, 2.3), 1, 0.2, a) for a in angles   ]


print(len(ells))

a = plt.subplot(111, aspect='equal')

for e in ells:
    e.set_clip_box(a.bbox)
    e.set_alpha(0.1)
    a.add_artist(e)
    #e.set_facecolor(1)

    
for e in ells1:
    e.set_clip_box(a.bbox)
    e.set_alpha(0.1)
    a.add_artist(e)
    e.set_facecolor('red')


plt.xlim(-4, 4)
plt.ylim(-4, 3)

plt.show()
# Out:
# 9

# %%
# import matplotlib.pyplot as plt
# import numpy as np
# from matplotlib.patches import Ellipse

# NUM = 250

# ells = [Ellipse(xy=np.random.rand(2) * 10,
#                 width=np.random.rand(), height=np.random.rand(),
#                 angle=np.random.rand() * 360)
#         for i in range(NUM)]

# fig, ax = plt.subplots(subplot_kw={'aspect': 'equal'})
# for e in ells:
#     ax.add_artist(e)
#     e.set_clip_box(ax.bbox)
#     e.set_alpha(np.random.rand())
#     e.set_facecolor(np.random.rand(3))

# ax.set_xlim(0, 10)
# ax.set_ylim(0, 10)

# plt.show()

# %%
print(np.random.rand(2) * 10)
# Out:
# [ 3.3134732   0.91589144]
